# %% [markdown]
# # Data wrangling

# %%
#import helper functions and other necessary packets
from helpers_f import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#to import entire data (not available on github)
newdf=pd.read_csv("./data/Flickrs-Switzerland-1990-2017.csv")

# %% [markdown]
# Extract year from datetaken and plot distribution per year

# %%
newdf['year']=newdf['datetaken'].map(lambda x: x[:4])

# %%
# %matplotlib inline
plt.hist(newdf.year.astype(int),bins=np.arange(1990,2018,1))
plt.show()

# %% [markdown]
# We see that it is meaningful to observe only trends from 2005 to 2016 (inclusive) as most of data comes from there. We plot a closer look

# %%
plt.hist(newdf.year.astype(int),bins=np.arange(2005,2018,1))
plt.show()

# %% [markdown]
# Get data only for the mentioned time period, extract months. We round latitude and longitude to 3 digits.

# %%
years_11=newdf[newdf['year'].astype(str).isin(["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016"])]

# %%
years_11['month']=newdf['datetaken'].map(lambda x: x[5:7])
# Out:
# /home/nevena/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
rounded_geo=years_11
rounded_geo['lat']=round(years_11['lat'].astype(float),3)
rounded_geo['lon']=round(years_11['lon'].astype(float),3)
# Out:
# /home/nevena/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/nevena/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# # Popular place per number of pictures

# %%
famous_place_per_year=rounded_geo.groupby(["year","lat","lon"]).count()

# %%
fam_places=famous_place_per_year[(famous_place_per_year.userid.isin(findmax(famous_place_per_year)))]

# %%
#we drop duplicates for 2008
fam_places=fam_places.reset_index().drop(fam_places.reset_index().index[[4]])

# %%
#display on the map
import folium
from IPython.display import HTML, display
SF_COORDINATES = (46,5)
map_2 = folium.Map(location=[46.85, 8.3], zoom_start=8)
for each in fam_places.reset_index().iterrows():
    folium.CircleMarker(location=[each[1]['lat'],each[1]['lon']], radius=each[1]['userid']*2,
                    popup=str(each[1]['year']), color='#3186cc',
                    fill_color='#C70039').add_to(map_2)
display(map_2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
#see what those places are, get their names
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
geolocator = Nominatim()
popular_places=[]
for index, row in fam_places.reset_index().iterrows():
    popular_places.extend([geolocator.reverse([row['lat'], row['lon']])])

# %%
pop_places=fam_places[['year','lat','lon','userid']]
pop_places['num_photos']=pop_places['userid']
pop_places=pop_places[['year','lat','lon','num_photos']]
pop_places['names']=getPlaceNames(popular_places)
pop_places
# Out:
# /home/nevena/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#     year     lat    lon  num_photos              names
# 0   2005  46.224  7.903         351        Staldenried
# 1   2006  47.256  9.109         727       Ebnat-Kappel
# 2   2007  47.560  7.585        1324              Basel
# 3   2008  46.693  6.911        4333        Romont (FR)
# 5   2009  46.693  6.912        3749        Romont (FR)
# 6   2010  47.459  8.242        1644           Mülligen
# 7   2011  46.235  6.119        2911  Le Grand-Saconnex
# 8   2012  46.693  6.911        1723        Romont (FR)
# 9   2013  46.168  6.119        2551    Plan-les-Ouates
# 10  2014  46.691  6.910        2361        Romont (FR)
# 11  2015  47.183  7.742        1636         Bleienbach
# 12  2016  46.168  6.119        1831    Plan-les-Ouates

# %% [markdown]
# We also want to check that it is based on similar number of users

# %%
pop_places['num_users']=tuple(map(lambda lat,lon,year: getNumUsers(rounded_geo,lat,lon,year),pop_places['lat'],pop_places['lon'],pop_places['year']))

# %%
pop_places
# Out:
#     year     lat    lon  num_photos              names  num_users
# 0   2005  46.224  7.903         351        Staldenried          1
# 1   2006  47.256  9.109         727       Ebnat-Kappel          1
# 2   2007  47.560  7.585        1324              Basel          2
# 3   2008  46.693  6.911        4333        Romont (FR)          1
# 5   2009  46.693  6.912        3749        Romont (FR)          2
# 6   2010  47.459  8.242        1644           Mülligen          1
# 7   2011  46.235  6.119        2911  Le Grand-Saconnex         18
# 8   2012  46.693  6.911        1723        Romont (FR)          2
# 9   2013  46.168  6.119        2551    Plan-les-Ouates          1
# 10  2014  46.691  6.910        2361        Romont (FR)          1
# 11  2015  47.183  7.742        1636         Bleienbach          2
# 12  2016  46.168  6.119        1831    Plan-les-Ouates          1

# %% [markdown]
# Romont is the most popular place, but we see that one users made most of these posts.<br> After checking the exact location of these posts (just someones house) we drop this user and reevaluate most popular places

# %%
without_bored_user=rounded_geo[rounded_geo.userid!='12359290@N04']
newFamous_plase=without_bored_user.groupby(["year","lat","lon"]).count()
new_places=newFamous_plase[(newFamous_plase.userid.isin(findmax(newFamous_plase)))]

# %%
#we drop duplicates for 2008
new_placec=new_places.reset_index().drop(new_places.reset_index().index[[4]])
new_placec
# Out:
#     year     lat    lon  userid  title  dateupload  datetaken  views  tags  \
# 0   2005  46.224  7.903     351    351         351        351    351   351
# 1   2006  47.256  9.109     727    727         727        727    727   727
# 2   2007  47.560  7.585    1324    215        1324       1324   1324  1324
# 3   2008  46.973  7.486    1343   1343        1343       1343   1343  1343
# 5   2009  46.615  7.045    1901   1901        1901       1901   1901  1899
# 6   2010  47.459  8.242    1644   1644        1644       1644   1644     0
# 7   2011  46.235  6.119    2911   2154        2911       2911   2911  2654
# 8   2012  46.277  6.170    1689   1682        1689       1689   1689  1637
# 9   2013  46.168  6.119    2551   2551        2551       2551   2551  2506
# 10  2014  47.113  6.846    2117   2117        2117       2117   2117  2115
# 11  2015  47.183  7.742    1636   1636        1636       1636   1636  1636
# 12  2016  46.168  6.119    1831   1831        1831       1831   1831  1831
#
#     place_id  woeid  month
# 0        351    351    351
# 1        727    727    727
# 2       1324   1324   1324
# 3       1343   1343   1343
# 5       1901   1901   1901
# 6       1644   1644   1644
# 7       2911   2911   2911
# 8       1689   1689   1689
# 9       2551   2551   2551
# 10      2117   2117   2117
# 11      1636   1636   1636
# 12      1831   1831   1831

# %%
#and again, we display on the map
map_3 = folium.Map(location=[46.85, 8.3], zoom_start=8)
for each in new_placec.reset_index().iterrows():
    folium.CircleMarker(location=[each[1]['lat'],each[1]['lon']], radius=each[1]['userid']*2,
                    popup=str(each[1]['year']), color='#3186cc',
                    fill_color='#C70039').add_to(map_3)
display(map_3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# As we saw before, next most popular place is Geneva (for 3 years). Let's find why is it so popular, what are the most popular tags?

# %%
new_most_pop_place_data=rounded_geo[((rounded_geo.lat==46.235) & (rounded_geo.lon==6.119)) |
                               ((rounded_geo.lat==46.277) & (rounded_geo.lon==6.170)) |
                               ((rounded_geo.lat==46.168) & (rounded_geo.lon==6.119))]

# %%
tagFreq(new_most_pop_place_data)
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                        word  freq
# 0             planlesouates  7987
# 1                    geneva  6252
# 2                  natation  5032
# 3               switzerland  4951
# 4                      show  4938
# 5                     motor  4506
# 6                    genève  3312
# 7                       car  3254
# 8                      auto  3148
# 9                     salon  2592
# 10                motorshow  2586
# 11                 swimming  2536
# 12                     genf  2379
# 13                  palexpo  2214
# 14            meetingmaster  2055
# 15                 autoshow  1994
# 16                   master  1961
# 17                 pressday  1944
# 18                   suisse  1937
# 19            international  1920
# 20                    march  1879
# 21                       ch  1821
# 22                     2011  1767
# 23                  versoix  1647
# 24    natationplanlesouates  1630
# 25                  juniors  1630
# 26     meetingstnicolas2015  1630
# 27                    canon  1625
# 28                       5d  1553
# 29                      eos  1513
# ...                     ...   ...
# 2469                   wcar     1
# 2470                    rct     1
# 2471                 inside     1
# 2472                    f12     1
# 2473                  types     1
# 2474                 museum     1
# 2475               isolated     1
# 2476                  slk55     1
# 2477                monitor     1
# 2478             countryman     1
# 2479                   hand     1
# 2480              microsoft     1
# 2481         gabicheminimal     1
# 2482            sudaviation     1
# 2483     ferraricaliforniat     1
# 2484              powershot     1
# 2485                  paris     1
# 2486              mamiya7ii     1
# 2487                 gasper     1
# 2488                   1987     1
# 2489                thierry     1
# 2490             hasselblad     1
# 2491              fireworks     1
# 2492                   aero     1
# 2493                    392     1
# 2494                    ds4     1
# 2495       christianwichard     1
# 2496                 takeri     1
# 2497           fbgparhermès     1
# 2498              gtconcept     1
#
# [2499 rows x 2 columns]

# %% [markdown]
# Based on first 10 tags we see that it is because of the car salon. Let's filter only pictures that contain only tags relevant to the car salon

# %%
geneva_salon_data=new_most_pop_place_data[new_most_pop_place_data['tags'].str.contains("auto") |
                                    new_most_pop_place_data['tags'].str.contains("car") |
                                    new_most_pop_place_data['tags'].str.contains("auto") |
                                    new_most_pop_place_data['tags'].str.contains("motor") |
                                    new_most_pop_place_data['tags'].str.contains("show") |
                                    new_most_pop_place_data['tags'].str.contains("motorshow") |
                                    new_most_pop_place_data['tags'].str.contains("autoshow") |
                                    new_most_pop_place_data['tags'].str.contains("salon")]

# %% [markdown]
# Discover evolution over time of this event

# %%
visitors=geneva_salon_data.groupby(['year','userid']).count().reset_index().groupby("year").count()

# %%
visitors['userid'].plot()
plt.show()

# %% [markdown]
# We see that Geneva auto salon was the most popular in 2012. Let's now check the most popular tag per year in the data that concerns this event in order to discover the most popular cars

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2005'])
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                     word  freq
# 0                    car    48
# 1                 geneva    31
# 2                carshow    30
# 3              autosalon    29
# 4                   auto    12
# 5            astonmartin    12
# 6         salondauto2005    12
# 7               maserati     6
# 8                  dodge     4
# 9                  viper     4
# 10                  mini     4
# 11             sportscar     4
# 12              prologue     3
# 13            conceptcar     3
# 14                 volvo     3
# 15                   407     3
# 16               peugeot     3
# 17             crossfire     3
# 18              chrysler     3
# 19                   c70     3
# 20                 froid     2
# 21            automotive     2
# 22               versoix     2
# 23                frozen     2
# 24                 honda     2
# 25              lacléman     2
# 26                 glace     2
# 27                toyota     2
# 28                winter     2
# 29                  2005     2
# ..                   ...   ...
# 48                 météo     1
# 49              icestorm     1
# 50             chevrolet     1
# 51           landcruiser     1
# 52                genève     1
# 53                   4x4     1
# 54          voituregelée     1
# 55                  gt40     1
# 56            stalactite     1
# 57               breyton     1
# 58                 glacé     1
# 59                    gt     1
# 60                 canon     1
# 61                 trees     1
# 62                celica     1
# 63         environnement     1
# 64  développementdurable     1
# 65            icecovered     1
# 66                 photo     1
# 67               bugatti     1
# 68            murcielago     1
# 69                veyron     1
# 70                  quai     1
# 71                  wind     1
# 72               coopers     1
# 73             lemanlake     1
# 74                suisse     1
# 75                   eis     1
# 76                digest     1
# 77              platanes     1
#
# [78 rows x 2 columns]

# %% [markdown]
# We see that the most popular car in 2005 was aston martin

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2006'])
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                      word  freq
# 0                  geneva   263
# 1                    show   263
# 2             switzerland   263
# 3                   motor   260
# 4                   nikon   251
# 5                     d50   244
# 6                     car   244
# 7                    auto   244
# 8                    2006   244
# 9               autosalon   244
# 10                  salon   244
# 11                 geneve   244
# 12             automobile   244
# 13               nikond50   244
# 14               autoshow   244
# 15                 europe   244
# 16              motorshow   244
# 17              prototype   148
# 18             conceptcar   147
# 19                concept    29
# 20                  jimmy    19
# 21                  james    19
# 22                   cars    19
# 23               ridewood    19
# 24                spadger    19
# 25                 toyota    18
# 26                classic    16
# 27                ferrari    12
# 28               maserati    12
# 29                porsche    12
# ..                    ...   ...
# 68                 veyron     1
# 69                   wcar     1
# 70            fulviacoupè     1
# 71                    ccx     1
# 72                    911     1
# 73                  miura     1
# 74                    gt3     1
# 75                   111r     1
# 76                   tcar     1
# 77                   mcar     1
# 78                 fulvia     1
# 79               koigsegg     1
# 80                  exige     1
# 81                  isuzu     1
# 82                   icar     1
# 83                   bcar     1
# 84                  coupè     1
# 85                   lada     1
# 86                 engine     1
# 87                   ycar     1
# 88                  royce     1
# 89                  coupé     1
# 90                   ucar     1
# 91                   fiat     1
# 92                  elise     1
# 93             rangerover     1
# 94  istitutoeuropeodesign     1
# 95                     f1     1
# 96                    ied     1
# 97                   rcar     1
#
# [98 rows x 2 columns]

# %% [markdown]
# Toyota was popular in 2006

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2007'])
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                       word  freq
# 0                   geneva   333
# 1              switzerland   213
# 2                     show   212
# 3                    motor   212
# 4                motorshow   208
# 5                     77th   208
# 6            international   207
# 7                     auto    80
# 8                     2007    80
# 9                    salon    80
# 10                    cars    50
# 11              doganowski    45
# 12              doganowscy    45
# 13                   dogan    45
# 14              doganowska    45
# 15                  europe    45
# 16                   trend     5
# 17                autoshow     5
# 18                  geneve     5
# 19  internationalmotorshow     1

# %% [markdown]
# No popular car in 2007

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2008'])[0:50]
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                        word  freq
# 0                      auto   170
# 1                      2008   139
# 2                conceptcar   117
# 3                       car   109
# 4                    geneva    96
# 5                     wheel    94
# 6                  supercar    92
# 7                  autoshow    92
# 8                   palexpo    91
# 9                   ginevra    91
# 10                  atelier    91
# 11                 dreamcar    91
# 12                supercars    91
# 13                  fashion    91
# 14                cardetail    91
# 15                   geneve    91
# 16                    light    91
# 17                  colours    91
# 18  ginevrasaloneautoeos40d    91
# 19            78thmotorshow    91
# 20                  voiture    90
# 21                   teewee    76
# 22                   genève    76
# 23             salondelauto    76
# 24                autosalon    16
# 25                  schweiz    15
# 26                       ge    15
# 27          legrandsaconnex    15
# 28               exhibition    15
# 29                      che    15
# 30                  fpm1979    12
# 31                  renault    12
# 32                   hermes     9
# 33                   nissan     9
# 34                  bugatti     9
# 35                   veyron     9
# 36                  edition     9
# 37                   mégane     8
# 38                  ferrari     7
# 39                       f1     7
# 40             competizione     6
# 41                  citroen     6
# 42                       8c     6
# 43                    mazda     5
# 44                    sport     5
# 45               sportwagen     5
# 46                alfaromeo     5
# 47                   spyker     4
# 48                    zonda     4
# 49                     jeep     4

# %% [markdown]
# We see some renault in 2008

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2009'])[0:50]
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                        word  freq
# 0                    geneva   145
# 1               switzerland   135
# 2                        ch   135
# 3                salondauto    97
# 4            genevaautoshow    97
# 5                      auto    94
# 6                   voiture    74
# 7                    geneve    74
# 8                    teewee    71
# 9                    genève    42
# 10                  schweiz    38
# 11                     genf    38
# 12                 svizzera    38
# 13    confederationhelvetic    38
# 14    confedrationhelvetica    38
# 15                   suisse    38
# 16    helveticconfederation    38
# 17  confédérationhélvétique    38
# 18   confédérationhelvetica    36
# 19                     cars    32
# 20                     2009    31
# 21                 voitures    23
# 22                    messe    23
# 23              exhibitions    23
# 24                   winter    23
# 25           transportation    23
# 26                    hiver    23
# 27                autosalon    23
# 28                  automne    15
# 29                 wwwgvach    15
# 30                   herbst    15
# 31                 aviation    15
# 32                     lsgg    15
# 33                      gva    15
# 34      wwwgenevaclassicsch    15
# 35                     fall    14
# 36                      bmw    13
# 37                    armée    12
# 38                militaire    12
# 39                     army    12
# 40            swissairforce    12
# 41                 military    12
# 42                     2008    11
# 43                   avione     9
# 44                    avion     9
# 45            genevacarshow     9
# 46                 airplane     9
# 47                 flugzeug     9
# 48                 aircraft     9
# 49                     audi     8

# %% [markdown]
# BMW in 2009

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2010'])[0:50]
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                    word  freq
# 0                   car   107
# 1              autoshow    99
# 2               vehicle    89
# 3               carshow    87
# 4               voiture    86
# 5                geneve    86
# 6          salondelauto    85
# 7                wheels    85
# 8   2010genevamotorshow    85
# 9              vehicule    85
# 10         genfautoshow    85
# 11           automobile    85
# 12       transportation    85
# 13               geneva    49
# 14                 auto    46
# 15              ginevra    35
# 16            motorshow    35
# 17                 cars    32
# 18                 2010    31
# 19               genève    27
# 20               salone    27
# 21            sportscar    23
# 22            autosalon    23
# 23        international    20
# 24          switzerland    20
# 25                bartw    19
# 26               nikkor    19
# 27                motor    19
# 28                nikon    19
# 29                d300s    19
# 30                 show    19
# 31           autogespot    18
# 32    bartwillemsteinnl    17
# 33           automotive    17
# 34            exoticcar    16
# 35                sedan    16
# 36              berline    14
# 37        autogespotcom    14
# 38           conceptcar    12
# 39                  bmw    12
# 40                 80th    12
# 41              peugeot    11
# 42        genevacarshow    11
# 43            alfaromeo    11
# 44                stand    11
# 45      genevamotorshow    11
# 46      salonediginevra    11
# 47           automobili    11
# 48                coupe    10
# 49                white    10

# %% [markdown]
# Bartwillemsteinnl in 2010

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2011'])[50:80]
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                         word  freq
# 50                canoneos7d   130
# 51                      81st   119
# 52                   carshow   119
# 53                   genève   116
# 54                   porsche    95
# 55                 beautiful    88
# 56                    geneve    85
# 57                     rolex    83
# 58          concourshippique    83
# 59           gillesforestier    83
# 60         canoneos1dmarkiii    83
# 61                  hippique    83
# 62                    famous    83
# 63                     horse    83
# 64              creditsuisse    83
# 65                  hippisme    83
# 66        equinephotographer    83
# 67                    cheval    83
# 68             interantional    83
# 69  professionalphotographer    83
# 70                      chiw    83
# 71                   jumping    83
# 72                      jump    83
# 73                     arena    83
# 74                   schweiz    79
# 75                 autosalon    79
# 76                   ferrari    79
# 77                     swiss    79
# 78                    people    78
# 79                     mujer    78

# %% [markdown]
# Porsche in 2011

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2012'])[0:50]
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                       word  freq
# 0                   geneva  1090
# 1                     2012  1069
# 2                motorshow  1008
# 3                    salon   996
# 4              switzerland   995
# 5                     genf   982
# 6                  palexpo   981
# 7                     auto   978
# 8                   suisse   978
# 9                     show   961
# 10                   motor   960
# 11                     car   925
# 12                   canon   914
# 13                     eos   912
# 14                      5d   904
# 15           journéepresse   902
# 16                    mars   902
# 17         genferautosalon   902
# 18  automobilsalongenf2012   902
# 19     genevamotorshow2012   902
# 20                autoshow   902
# 21  genevacarshowpressdays   902
# 22     automobilemotorshow   902
# 23                pressday   902
# 24                   march   902
# 25                  photos   902
# 26               beautiful   450
# 27                   woman   445
# 28                   belle   445
# 29                    lady   445
# 30                   girls   445
# 31                  lovely   445
# 32                    babe   445
# 33                     hot   445
# 34                 hotesse   445
# 35                    sexy   445
# 36                   donna   445
# 37                    girl   445
# 38                  people   445
# 39                   jolie   445
# 40                   women   445
# 41                   femme   445
# 42              mostviewed   445
# 43                beauties   445
# 44               mannequin   445
# 45                    frau   445
# 46                  femmes   445
# 47                  beauty   445
# 48                   mujer   445
# 49                 popular   445

# %% [markdown]
# No popular car in 2012

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2013'])[59:]
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                                         word  freq
# 59                                 worldcars    58
# 60                                         g    57
# 61                                       amg    50
# 62                                      benz    48
# 63                                  mercedes    48
# 64                                         b    48
# 65                                         s    43
# 66                                       rot    34
# 67                                        rs    33
# 68                                         w    33
# 69                                        mb    32
# 70                                     sport    31
# 71                                       bmw    31
# 72                                   porsche    30
# 73                                         t    29
# 74                                         r    26
# 75                                        gt    26
# 76                                       red    26
# 77                                     white    24
# 78                                         f    22
# 79                                    bayern    22
# 80   saloninternationaldesinventionsdegenève    21
# 81                                      ompi    21
# 82                      genevainventionsfair    21
# 83                                      wipo    21
# 84                                   palexpo    21
# 85                                  leonberg    18
# 86                                     weiss    18
# 87                                  inventor    18
# 88                                   gembala    18
# ..                                       ...   ...
# 397                               blackwhite     1
# 398                                     lens     1
# 399                                  schweit     1
# 400                                    ftype     1
# 401                                   klasse     1
# 402                         christianwichard     1
# 403                            deloreandmc12     1
# 404                    deputydirectorgeneral     1
# 405                                     grün     1
# 406                                    rosso     1
# 407                                      art     1
# 408                                   yallow     1
# 409                                    vetel     1
# 410                                     tech     1
# 411                                   sbarro     1
# 412                                     helm     1
# 413                                 spanogta     1
# 414                                       ex     1
# 415                                        9     1
# 416                                rennwagen     1
# 417                                      apo     1
# 418                                    f3545     1
# 419                                   center     1
# 420                                      f28     1
# 421                               grandsport     1
# 422                                      rb9     1
# 423                                   vettel     1
# 424                                     rgt8     1
# 425                                       p4     1
# 426                                  quattro     1
#
# [368 rows x 2 columns]

# %% [markdown]
# Mercedes in 2013

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2014'])[0:50]
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                             word  freq
# 0                         geneva  1530
# 1                           show  1516
# 2                           84th  1490
# 3                  international  1490
# 4                          motor  1490
# 5                           2014  1117
# 6                        concept   329
# 7                      endurance   206
# 8                           mans   206
# 9                         racing   188
# 10                            du   177
# 11  genevainternationalmotorshow   177
# 12                            24   177
# 13                 lemanslegends   177
# 14                        heures   177
# 15               genevamotorshow   151
# 16                   anthonygurr   149
# 17                           car    84
# 18                     crossover    75
# 19                        design    74
# 20                        pagani    69
# 21                       hyundai    54
# 22                        hybrid    48
# 23                          cell    46
# 24                         coupe    46
# 25                       intrado    46
# 26                          fuel    46
# 27                        geneve    43
# 28                          cars    43
# 29                     prototype    41
# 30                        genève    39
# 31                         mark3    38
# 32                   rafdebruyne    38
# 33                       5dmkiii    38
# 34                           eos    38
# 35               canoneos5dmkill    38
# 36                         canon    38
# 37                     5dmarkiii    38
# 38                   debruyneraf    38
# 39                           mk3    38
# 40                 canoneos5dmk3    38
# 41               canoneos5dmkiii    38
# 42                            5d    38
# 43        debruynerafphotography    38
# 44                          genf    37
# 45                       carshow    37
# 46                         zonda    35
# 47                    revolucion    35
# 48                   lamborghini    34
# 49                       porsche    33

# %% [markdown]
# Le mans legends in 2014 (didn't even know that this is a car)

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2015'])[59:]
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                                    word  freq
# 59                               modèle    80
# 60                              hôtesse    80
# 61                                   df    70
# 62                                coupé    49
# 63                            prototype    49
# 64                           conceptcar    49
# 65                                  4x4    38
# 66                                  awd    38
# 67                                  4wd    38
# 68                          lamborghini    29
# 69                           exhibition    24
# 70                                 expo    24
# 71                           exposition    24
# 72                            worldcars    23
# 73                                 cars    23
# 74                              offroad    23
# 75                                  suv    23
# 76                                sport    23
# 77                            crossover    22
# 78                  genevamotorshow2015    22
# 79                              mclaren    21
# 80                                 audi    21
# 81                              carshow    21
# 82                                   ze    20
# 83                         zeroemission    20
# 84         internationalerautosalongenf    19
# 85                                 sony    19
# 86   saloninternationaldel’autodegenève    19
# 87                                rx100    19
# 88                      canoneos5dmkill    18
# ..                                  ...   ...
# 582                              wheels     1
# 583                            3wheeler     1
# 584                             gklasse     1
# 585                              touran     1
# 586                                gran     1
# 587                              cayman     1
# 588                             lafinal     1
# 589                            series31     1
# 590                              megane     1
# 591                             vantage     1
# 592                            audirs6r     1
# 593                                 rct     1
# 594                              turkey     1
# 595                                tata     1
# 596                                 164     1
# 597                          dakarrally     1
# 598                        mbs634maticc     1
# 599                                 sls     1
# 600                                 850     1
# 601                               flare     1
# 602                               tesla     1
# 603                                  la     1
# 604                                x222     1
# 605               brabus850mbs634maticc     1
# 606                                  fr     1
# 607                           sportback     1
# 608                                2008     1
# 609                            rinspeed     1
# 610                             citroën     1
# 611                             mustang     1
#
# [553 rows x 2 columns]

# %% [markdown]
# Lamborghini in 2015

# %%
tagFreq(geneva_salon_data[geneva_salon_data['year']=='2016'])
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)
#                word  freq
# 0              2016   135
# 1         motorshow   111
# 2            racing   109
# 3               car   108
# 4          supercar   108
# 5         exclusive   108
# 6     international   108
# 7            geneve   107
# 8             retro   107
# 9              auto   107
# 10          classic   106
# 11       classiccar   106
# 12       conceptcar   106
# 13       vintagecar   106
# 14          concept   106
# 15    rassemblement   106
# 16          vintage   106
# 17             gims   101
# 18           geneva    32
# 19            motor    30
# 20             show    29
# 21          renault    14
# 22          porsche    14
# 23        chevrolet    12
# 24         corvette    11
# 25       koenigsegg    11
# 26          peugeot    10
# 27            dakar     9
# 28              gt3     9
# 29               f1     8
# ..              ...   ...
# 207          i20wrc     1
# 208             new     1
# 209          wrxsti     1
# 210     performance     1
# 211               r     1
# 212    superleggera     1
# 213            blue     1
# 214            hemi     1
# 215         hyundai     1
# 216       civicwtcc     1
# 217          gt3rsr     1
# 218           photo     1
# 219              r1     1
# 220            308r     1
# 221            gt86     1
# 222             i20     1
# 223             brm     1
# 224       gtconcept     1
# 225   porsche911rsr     1
# 226     huracanavio     1
# 227         miniwrc     1
# 228              p1     1
# 229    discovolante     1
# 230     carbonfiber     1
# 231           fiber     1
# 232             v10     1
# 233          camaro     1
# 234         charger     1
# 235         dempsey     1
# 236  ds3performance     1
#
# [237 rows x 2 columns]

# %% [markdown]
# Some vintage car in 2016

# %% [markdown]
# ### Let's see some pictures

# %% [markdown]
# Get pictures using API

# %%
urls=[getUrlForTags("motorshow",46.168,6.119,2005,-1)[0]['url_m'],
      getUrlForTags("motorshow",46.235,6.119,2006,-1)[1]['url_m'],
      getUrlForTags("motorshow",46.235,6.119,2007,-1)[1]['url_m'],
      getUrlForTags("motorshow",46.235,6.119,2008,-1)[2]['url_m'],
      getUrlForTags("motorshow",46.168,6.119,2009,-1)[1]['url_m'],
      getUrlForTags("motorshow",46.168,6.119,2010,-1)[2]['url_m'],
      getUrlForTags("motorshow",46.168,6.119,2011,-1)[4]['url_m'],
      getUrlForTags("motorshow",46.168,6.119,2012,-1)[0]['url_m'],
      getUrlForTags("motorshow",46.168,6.119,2013,-1)[6]['url_m'],
      getUrlForTags("motorshow",46.168,6.119,2014,-1)[20]['url_m'],
      getUrlForTags("motorshow",46.168,6.119,2015,-1)[14]['url_m'],
      getUrlForTags("motorshow",46.168,6.119,2016,-1)[6]['url_m']
    ]

# %%
#save these images just in case
import urllib.request
for i in urls:
    urllib.request.urlretrieve(i,'./geneva_salon/'+str(2005+urls.index(i)))

# %%
df_genev=geneva_salon_data[['year','userid']].groupby('year').count().reset_index()

# %%
#we read files localy 
from os import listdir
from os.path import isfile,join
urls=[f for f in listdir('./geneva_salon/') if isfile(join('./geneva_salon/', f))]

# %%
# %matplotlib qt
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import Circle
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from matplotlib.cbook import get_sample_data
from skimage import io

fig, ax = plt.subplots()
fig.suptitle('Popular cars in Geneva Car Salon', fontsize=14)
ax.bar(df_genev.year.astype(int),df_genev.userid,picker=True,color='lightsalmon')

def onpick3(event):   
    artist = event.artist
     
    i=int(event.artist.get_x())
    xy=[i,df_genev[df_genev.year==str(i)]['userid']]
  
    file=os.path.join('./geneva_salon/',urls[i-2005])
    a = io.imread(file,format='png')

    imagebox = OffsetImage(a, zoom=0.7)
    imagebox.image.axes = ax
    normalize=[0,0]
    if((i==2011) | (i==2014)): normalize=[-200,-150]
    ab = AnnotationBbox(imagebox, xy,
                        xybox=(100+normalize[0],150+normalize[1]),
                        xycoords='data',
                        boxcoords="offset points",
                        pad=0.3,
                        arrowprops=dict(arrowstyle="->"))
    ax.add_artist(ab)
    event.canvas.draw()
    ab.remove()
        
fig.canvas.mpl_connect('pick_event', onpick3)
plt.show()

# %% [markdown]
# # Popular places by number of users

# %%
most_users=rounded_geo.groupby(["lat","lon","year","userid"]).count()

# %%
user_per_loc=most_users.reset_index().groupby(['lat','lon','year'])['userid'].nunique()

# %%
users_per_loc=pd.DataFrame(user_per_loc).sort('userid',ascending=False).reset_index()
# Out:
# /home/nevena/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
df=pd.DataFrame(index=range(2005,2017),columns=['lat','lon','userid'])
for x in range(2005,2017):
    max_num=max(users_per_loc[users_per_loc['year']==str(x)]['userid'])
    data=users_per_loc[(users_per_loc['year']==str(x)) & (users_per_loc['userid']==max_num)]
    df.set_value(x, 'lat', data['lat'].values[0])
    df.set_value(x, 'lon', data['lon'].values[0])
    df.set_value(x, 'userid', data['userid'].values[0])

# %% [markdown]
# Most popular place is 47.377 8.54 almost in all years. Let's see what it is

# %%
data_most_pop=rounded_geo[(rounded_geo.lat==47.377) & (rounded_geo.lon==8.54)]
df=pd.DataFrame(columns=['year','word','freq'])
for year in range(2005,2017):
    df=df.append(pd.DataFrame(tagFreq(data_most_pop[data_most_pop.year==str(year)],year)),ignore_index=True)
# Out:
# /home/nevena/Desktop/ADA-Project/helpers_f.py:54: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dfWords=dfWords.sort(['freq'],ascending=False)

# %%
pop_tags_for_pop_location_per_year=df[(df.word!="zurich") & (df.word!="zürich")& (df.word!="swiss")& (df.word!="schweiz")
   & (df.word!="suisse")& (df.word!="switzerland") & (df.word!="svizzera") & (df.freq>5)].set_index(["year","freq"])
pop_tags_for_pop_location_per_year
# Out:
#                                 word
# year   freq
# 2005.0 14.0           bahnhofstrasse
#        13.0                 shopping
#        13.0                christmas
#        13.0                    daily
#        13.0                 camphone
#        13.0                    k750i
#        9.0                bellinzona
#        9.0                      chur
#        9.0                    lugano
#        8.0                  downtown
#        7.0                 buildings
#        6.0                     river
# 2006.0 22.0  geo:country=switzerland
#        22.0          geo:city=zurich
#        16.0                     food
#        15.0                     city
#        11.0             hauptbahnhof
#        9.0                       vbz
#        9.0                       sbb
#        8.0                     train
#        8.0                trammuseum
#        7.0                       d50
#        7.0               mainstation
#        7.0                    ©toniv
#        7.0                     toniv
#        7.0                    europe
#        6.0                      2006
# 2007.0 31.0              freestylech
#        29.0                      vbz
#        26.0               trammuseum
# ...                              ...
# 2015.0 9.0                    square
#        9.0     uploaded:by=instagram
#        9.0              squareformat
#        9.0             iphoneography
#        9.0              instagramapp
#        8.0                     white
#        8.0                        bw
#        8.0                      2015
#        7.0                     black
#        6.0                      tram
#        6.0                    winter
# 2016.0 12.0                       bw
#        11.0                   street
#        11.0                   europe
#        11.0            blackandwhite
#        10.0                    urban
#        10.0        streetphotography
#        9.0             ivanrigamonti
#        9.0                       bnw
#        9.0          urbanexploration
#        8.0                       man
#        8.0                      2016
#        8.0                        ch
#        7.0                    flickr
#        7.0                     500px
#        7.0            bahnhofstrasse
#        6.0                 backlight
#        6.0         zurichmainstation
#        6.0                monochrome
#        6.0                    people
#
# [1219 rows x 1 columns]

# %%
#pictures are manually chosen
df=users_per_loc[(users_per_loc.lat==47.377) & (users_per_loc.lon==8.54)][['year','userid']]
urls=[getUrlForTags("bahnhofstrasse",47.377,8.54,2005,-1)[0]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2006,-1)[5]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2007,-1)[2]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2008,-1)[9]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2009,-1)[4]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2010,-1)[2]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2011,-1)[0]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2012,-1)[0]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2013,-1)[1]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2014,-1)[9]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2015,-1)[5]['url_m'],
        getUrlForTags("bahnhofstrasse",47.377,8.54,2016,-1)[54]['url_m']]

# %%
#save images just in case
for i in urls:
    urllib.request.urlretrieve(i,'./train_station/'+str(2005+urls.index(i)))

# %%
#we read files localy 
from os import listdir
from os.path import isfile,join
urls=[f for f in listdir('./train_station/') if isfile(join('./train_station/', f))]

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import Circle
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from matplotlib.cbook import get_sample_data
from skimage import io

fig, ax = plt.subplots()
fig.suptitle('Zurich train station over time\nClick on the bar to display a picture', fontsize=14)
ax.bar(df.year.astype(int),df.userid,picker=True,color='lightsalmon')

def onpick3(event):   
    artist = event.artist
     
    i=int(event.artist.get_x())
    xy=[i,df[df.year==str(i)]['userid']]
  
    file=os.path.join('./train_station/',urls[i-2005])
    a = io.imread(file,format='png')

    imagebox = OffsetImage(a, zoom=0.7)
    imagebox.image.axes = ax
    normalize=[0,0]
    if((i>2009) & (i<2014)): normalize=[-200,-150]
    ab = AnnotationBbox(imagebox, xy,
                        xybox=(100+normalize[0],150+normalize[1]),
                        xycoords='data',
                        boxcoords="offset points",
                        pad=0.3,
                        arrowprops=dict(arrowstyle="->"))
    ax.add_artist(ab)
    event.canvas.draw()
    ab.remove()
        
fig.canvas.mpl_connect('pick_event', onpick3)
plt.show()

# %% [markdown]
# # Number of posts per month, daytime

# %%
newdf=rounded_geo
newdf['time']=newdf['datetaken'].map(lambda x: datetime.datetime.strptime(x[11:],'%H:%M:%S').time())

# %%
newdf['daytime']=newdf['time'].map(lambda x: daytime(x))

# %%
newdf.groupby(['daytime']).count()[['userid']]
# Out:
#             userid
# daytime
# afternoon  1379243
# evening     548584
# morning     682812
# night       178844

# %%
newdf['month']=newdf['datetaken'].map(lambda x: x[5:7])
perDayTime=newdf.groupby(['month','daytime']).count()[['userid']].reset_index()

# %%
perDayTime.pivot_table(index='month', columns='daytime', values='userid',
                aggfunc='sum', fill_value=0).plot.bar(stacked=True)

# %% [markdown]
# # Word cloud per canton

# %%
import pickle

# load canton mapings from pickled data
with open('./data/df3.pickle', 'rb') as handle:
    cantons = pickle.load(handle)

# %%
loc_tags=newdf[['tags','lat','lon']]

# %%
loc_tags['location']= newdf.iloc[0:newdf.shape[0]-1, 6:8].apply(lambda x: str(x[0]) + ', ' + str(x[1]), axis=1)
# Out:
# /home/nevena/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
loc_tags=loc_tags[['tags','location']]

# %%
loc_tags=loc_tags.dropna()

# %%
frame=loc_tags.groupby('location')['tags'].sum()

# %%
tags_per_loc=pd.DataFrame(frame)

# %%
cantons_tags=cantons.set_index('location').join(tags_per_loc).reset_index()[['canton','tags']]

# %%
grouped_ca=cantons_tags.dropna().groupby('canton').sum()

# %%
only_swiss=grouped_ca.drop(['Auvergne-Rhône-Alpes','Baden-Württemberg','Bourgogne-Franche-Comté','Grand-Est','Hauts-de-France',
                'LOM','PIE','TAA','Tirol','VDA','VEN','Vorarlberg'])

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from os import path
from scipy.misc import imread
from matplotlib import colors as mcolors
import six
import random
          
def color_f(word, font_size, position, orientation, random_state=None, **kwargs):
        if(count*10)<100:
            color_pal='rgb('+str(count*10)+'%%,'+str(int(100/(count+1)))+'%%,%d%%)'
        else:
            color_pal='rgb('+str(int(100/3*(count+1)))+'%%,'+str(count*3)+'%%,%d%%)'
        return color_pal % random.randint(0, 30)


exclude=['switzerland', 'schweiz', 'suisse', 'svizzera', 'svizra', 'suiza', ',europe','europe','geo',',geo', 'lon', 'lat', 
                   'img', 'ch', 're', 'jpg', 'dsc', 'che', 've', 'in', 'the', 'zrh','fr', 'the', 'for', 'mm', 'geolon', 
                   'geolat', 'swiss', 'swis', 'nikon','europa','photo','photographe','geotagged','analog','analogue','canon','fuji','fujifilm','film',
        'canton', 'kanton', 'city', 'ville', 'country', 'geneve', 'gva', 'town', 'd40', 'd700', 'd4', '400d', '8800f', '35mm', 'f28', 's6000fd', 's6500fd']
for word in exclude:
    STOPWORDS.add(word)
    
count=0
for name in only_swiss.index.values:
    mymask = imread("./cantons/maps/"+name+".png",flatten=True)
    wc = WordCloud(background_color='white', max_words=2000, mask=mymask,stopwords=STOPWORDS).generate(only_swiss.ix[name]['tags'])
    plt.imshow(wc.recolor(color_func=color_f,random_state=count))
    count=count+1
    plt.axis('off')
    plt.savefig('./clouds/'+name+'2.png', dpi=300,transparent=True)
# Out:
# /home/nevena/anaconda3/lib/python3.5/site-packages/wordcloud/wordcloud.py:286: UserWarning: mask image should be unsigned byte between 0 and 255. Got a float array
#   warnings.warn("mask image should be unsigned byte between 0 and"

# %%
# %matplotlib inline
from IPython.display import Image
from IPython.display import display
from IPython.display import HTML
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir('./word_clouds/') if isfile(join('./word_clouds/', f))]
    
imagesList=''.join( ["<img style='width: 320px; margin: -30px; float: left;' src='%s' />" % str("./word_clouds/"+s) 
                 for s in onlyfiles ])
display(HTML(imagesList))
# Out:
# <img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Graubünden - Grigioni - Grischun2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Uri2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Appenzell Innerrhoden2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Ticino2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Sankt Gallen2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Thurgau2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Valais - Wallis2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Zürich2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Nidwalden2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Obwalden2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Luzern2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Basel-Landschaft2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Glarus2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Bern - Berne2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Schaffhausen2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Jura2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Basel-Stadt2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Neuchâtel2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Schwyz2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Solothurn2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Genève2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Vaud2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Appenzell Ausserrhoden2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Fribourg - Freiburg2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Aargau2.png' /><img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Zug2.png' />

# %% [markdown]
# <img style='width: 320px; margin: -30px; float: left;' src='./word_clouds/Uri2.png' />

# %% [markdown]
# # Bubbles

# %%
data=newdf

# %%
data.dropna(subset=['userid','tags'], how='all', inplace= True)

# %%
data['tags'] = data[['title', 'tags']] \
                        .apply(lambda x : fill_nan(str(x['tags']), str(x['title'])), axis=1)

# %%
#keep only the relevent columns
data = data[['userid', 'datetaken', 'views', 'tags', 'lat', 'lon']]
data =data.ix[1:]

# %%
data['tags'] = data.tags.apply(lambda x: preprocessor(str(x)))

# %%
import pickle
with open('./data/df3.pickle', 'rb') as handle:
    d = pickle.load(handle)

# %%
mapping = pd.DataFrame(d[['canton']])
mapping.index = d.location

# %%
cantonDict = mapping.to_dict()
cantonDict = cantonDict.get('canton')

# %%
abbr = dict([('Aargau', 'AG'), 
      ('Appenzell Ausserrhoden', 'AR'), 
      ('Appenzell Innerrhoden', 'AI'), 
      ('Basel-Landschaft', 'BL'), 
      ('Basel-Stadt', 'BS'), 
      ('Bern - Berne', 'BE'), 
      ('Fribourg - Freiburg', 'FR'), 
      ('Genève', 'GE'), 
      ('Glarus', 'GL'), 
      ('Graubünden - Grigioni - Grischun', 'GR'), 
      ('Jura', 'JU'), 
      ('Luzern', 'LU'), 
      ('Neuchâtel', 'NE'), 
      ('Nidwalden', 'NW'), 
      ('Obwalden', 'OW'), 
      ('Schaffhausen', 'SH'), 
      ('Schwyz', 'SZ'), 
      ('Solothurn', 'SO'), 
      ('Sankt Gallen', 'SG'), 
      ('Thurgau', 'TG'), 
      ('Ticino', 'TI'), 
      ('Uri', 'UR'), 
      ('Valais - Wallis', 'VS'), 
      ('Vaud', 'VD'), 
      ('Zug', 'ZG'), 
      ('Zürich', 'ZH')
     ])

# %%
data['canton'] = 'none'
data['canton'] = data[['lat', 'lon']].apply(mapCanton, axis= 1)
data = data[(pd.notnull(data.canton))&(data.canton != 'other')]

# %%
data['year']= data['datetaken'].map(lambda x: x[:4])
data['month']= data['datetaken'].map(lambda x: x[5:7])

# %%
data['year'] = data.year.astype(int)
data['views'] = data.views.astype(int)
data['month'] = data.month.astype(int)
#drop rows whose both title and tags are null
data.dropna(subset=['tags'], how='any', inplace= True)
data = data.loc[(data.year > 2004) & (data.tags != "nan") & (data.tags != "none")]

# %%
data1 = data.copy()

# %% [markdown]
# Plot data per canton

# %%
data_co = data.groupby("canton")['userid'].count()
plt.style.use('ggplot')
_ = data_co.plot.pie(figsize=(10, 10))

# %%
top5_canton = data_co.to_frame()
top5_canton.sort(['userid'], ascending=[False], inplace=True)

# %%
cantons = list(top5_canton.head(5).index.values.astype(str))
cantons
# Out:
# ['BE', 'ZH', 'VD', 'GE', 'VS']

# %%
#get the top 10 tags
def top_10_tags(df):
    return df.head(15)


def preprocessor_2(tags):
    
    remove_words =['switzerland', 'schweiz', 'suisse', 'svizzera', 'svizra', 'suiza', 'europe' 'geo', 'lon', 'lat', 
                   'img', 'ch', 're', 'jpg', 'dsc', 'che', 've', 'in', 'the', 'zrh','fr', 'the', 'for', 'mm',
                   'europe', 'wallis', 'geolon', 'geolat', 'geneva', 'geneve', 'gen', 'genf', 'ginebra', 'ginevra', 'exif',
                   'gva', 'de', 'vaud', 'valais','vallis', 'zurich', 'rich', 'imag', 'europe', 'zuerich', 'zu', 'geo', 'zuerich',
                   'Bern', 'Berne', 'bern', 'berne' 'swiss']
    tags = ' '.join([word for word in tags.split(' ') if ((not len(word) < 3) & (not word in remove_words))])
    tags = re.sub(r'(^(  ?)|(  ?)$)', '', tags)
    if (len(tags) == 0): return np.nan
    return tags

# %%
df = pd.DataFrame(index=list(abbr.keys()), columns=np.arange(2005, 2017, 1))

# %%
data = data1.copy()

# %%
data['year']=data['datetaken'].map(lambda x: x[:4])

# %%
for canton in list(abbr.values()):
    for year in np.arange(2005, 2017, 1):
        top_10 = top_10_tags(tagFreq(data[(data.canton == canton) & (data.year == str(year))]))
        index = list(abbr.keys())[list(abbr.values()).index(canton)]
        df.ix[index, year] = preprocessor_2(' '.join(top_10.word.values))

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import plotly as plotly
plotly.tools.set_credentials_file(username='nhallxd', api_key='218crnnLi3oOMTM9ICDV')
import plotly.plotly as py
import plotly.graph_objs as go

import pickle
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6) 
path = "./"
from subprocess import check_output

from wordcloud import WordCloud, STOPWORDS

import warnings
warnings.filterwarnings("ignore")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
num_per_canton_year=data1.groupby(["canton","year"]).count()

# %%
num_per_canton_year=num_per_canton_year.reset_index()

# %%
only_per_canton=data1.groupby(["canton"]).count()

# %%
only_per_canton=only_per_canton.sort(["userid"],ascending=True).reset_index()

# %% [markdown]
# Plot 5 most popular tags per canton and per year

# %%
data=[]
for ab in list(abbr.values()):
    index = list(abbr.keys())[list(abbr.values()).index(str(ab))]
    val = list(df[df.index == index].values[0])
    sizes=num_per_canton_year[(num_per_canton_year['canton']==str(ab))]['userid']
    sizes=sizes.map(lambda x: x/50)
    y_value=only_per_canton[only_per_canton['canton']==str(ab)].index.tolist()[0]
    trace0 = go.Scatter(
        x= df.columns.values,
        y= np.arange(10+(y_value*50), 23+(y_value*50), 1),
        text=list(map(lambda x: " ".join(x.split(" ")[:5]), val)),
        name= index,
        mode='markers',
        marker=dict(
            size=sizes,
            sizemode='area'
        )
    )
    data.extend([trace0])
layout = go.Layout(
    autosize=False,
    width=1000,
    height=700,
    xaxis=dict(
        title='Year',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='nlack'
        ),
        showticklabels=True,
        tickangle=45,
        tickfont=dict(
            family='Old Standard TT, serif',
            size=14,
            color='black'
        ),
        exponentformat='e',
        showexponent='All'
    ),
    yaxis=dict(
        title='Popularity of a canton',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='black'
        ),
        showticklabels=True,
        tickangle=45,
        tickfont=dict(
            family='Old Standard TT, serif',
            size=14,
            color='black'
        ),
        exponentformat='e',
        showexponent='All'
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Trend')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~nhallxd/0 or inside your plot.ly account where it is named 'Trend'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nhallxd/0.embed" height="700px" width="1000px"></iframe>
